# %%
# notebooks/validation/03_validate_enrichment.ipynb

import pandas as pd

# 1. Load enriched data
df = pd.read_parquet("../../data/processed/incidents_enriched.parquet")
print("Shape:", df.shape)
df.head()

# 2. Column overview
df.info()

# 3. Null value report
df.isna().mean().sort_values(ascending=False).to_frame("null_ratio")

# 4. Categorical distributions
categoricals = [
    "ride_type", "season", "day_of_week", "age_group", "gender",
    "incident_type", "simulated_medical_condition"
]
for col in categoricals:
    print(f"\n🧾 {col}:")
    print(df[col].value_counts(dropna=False))

# 5. Numeric sanity checks
df[["age", "duration_min"]].describe()

# 6. Logical consistency
print("\nAge vs. is_minor")
print(df["age"].where(df["is_minor"] == True).min(), "← youngest minor")
print(df["age"].where(df["is_minor"] == False).max(), "← oldest non-minor")

print("\nAge vs. is_senior")
print(df["age"].where(df["is_senior"] == True).min(), "← youngest senior")

print("\nday_of_week vs. is_weekend")
print(df[["day_of_week", "is_weekend"]].drop_duplicates().sort_values("day_of_week"))

# 7. Simulated feature confirmation
print("\nSimulated features:")
print("→ simulated_medical_condition (controlled randomness)")
print("→ first_time_visitor (Bernoulli 40%)")
print("first_time_visitor mean:", df["first_time_visitor"].mean())
print("simulated_medical_condition distribution:")
print(df["simulated_medical_condition"].value_counts(normalize=True))

# 8. Optional: export nulls
df.isna().sum().to_csv("../../outputs/reports/nulls_enriched.csv")
# Out:
# Shape: (682, 23)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   company                      682 non-null    object
#  1   incident_date                682 non-null    object
#  2   ride_name_dirty              682 non-null    object
#  3   ride_name                    682 non-null    object
#  4   theme_park                   682 non-null    object
#  5   age_gender                   682 non-null    object
#  6   description                  682 non-null    object
#  7   incident_date_parsed         682 non-null    datetime64[ns]
#  8   age                          682 non-null    int64
#  9   gender                       682 non-null    object
#  10  incident_type                682 non-null    object
#  11  ride_type                    518 non-null    object
#  12  duration_min                 461 non-null    float64
#  13  day_of_week                  682 non-null    object
#  14  month                        682 non-null    int32
#  15  is_weekend                   682 non-null    bool
#  16  is_summer                    682 non-null    bool
#  17  season                       682 non-null    object
#  18  age_group                    682 non-null    category
#  19  is_minor                     682 non-null    bool
#  20  is_senior                    682 non-null    bool
#  21  simulated_medical_condition  682 non-null    object
#  22  first_time_visitor           682 non-null    bool
# dtypes: bool(5), category(1), datetime64[ns](1), float64(1), int32(1), int64(1), object(13)
# memory usage: 92.4+ KB
#
# 🧾 ride_type:
# ride_type
# None                                      164
# Dark ride,motion simulator                 44
# Steel–Dual-tracked–Enclosed                39
# Space simulator                            36
# Dark ride                                  36
# Steel–Enclosed–Launched                    23
# Steel–Launched–Enclosed                    21
# Shooting dark ride                         20
# Steel                                      18
# Drop towerdark ride,haunted attraction     16
# 3-DMotion simulator                        16
# Steel–Launched                             15
# 3Dflying simulator                         15
# People mover                               15
# EMVdark ride                               14
# Steel–Mine train                           12
# Dark ride/haunted attraction               12
# Steel–Inverted–Dueling                     11
# Aquarium/Dark ride                         10
# Carousel                                   10
# Teacups                                    10
# Log flume                                  10
# Flying Theatersimulator ride                9
# Rail-suspendeddark ride                     8
# Pavilion                                    8
# Suspendeddark ride                          7
# Division                                    6
# River rapids ride                           6
# Backlot tour dark ride                      6
# Tow boat ride                               6
# Slot car                                    6
# Sternwheeler                                5
# Boat Canal                                  4
# Motion Simulator                            4
# Old Mill                                    3
# IMAX Domemotion simulator[1]                3
# Motion-based3Ddark ride                     3
# Steel–Junior                                3
# Tracklessdark ride                          2
# Aerial carousel                             2
# Steel–Family–Launched                       2
# Space shot                                  2
# 3-DSpecial Effects Ride                     2
# Heritage railroad                           2
# Shoot the chute                             2
# 3Dand live action show                      1
# Aerial Carousel                             1
# Spinning                                    1
# Tram tour                                   1
# Motion simulator/ tracklessdark ride        1
# Steel–Spinning–Wild Mouse                   1
# Boat ride                                   1
# Musical Boat Cruise/Shoot the Chute         1
# Print (hardcover)                           1
# Annual event                                1
# ReversingShoot the Chute/Dark ride          1
# Subway Train                                1
# OMNIMAXmotion simulator                     1
# Heritage railway                            1
# Name: count, dtype: int64
#
# 🧾 season:
# season
# summer    194
# spring    188
# winter    153
# fall      147
# Name: count, dtype: int64
#
# 🧾 day_of_week:
# day_of_week
# Tuesday      111
# Sunday       102
# Friday       101
# Saturday      98
# Thursday      96
# Monday        88
# Wednesday     86
# Name: count, dtype: int64
#
# 🧾 age_group:
# age_group
# 50–59    139
# 60–69    130
# 70+      128
# 40–49    125
# 30–39     51
# 10–19     45
# 20–29     42
# <10       22
# Name: count, dtype: int64
#
# 🧾 gender:
# gender
# F    365
# M    317
# Name: count, dtype: int64
#
# 🧾 incident_type:
# incident_type
# medical         290
# motion          191
# trauma           90
# other            60
# fall             38
# pre_existing     13
# Name: count, dtype: int64
#
# 🧾 simulated_medical_condition:
# simulated_medical_condition
# none        479
# asthma       60
# cardiac      53
# diabetes     51
# epilepsy     39
# Name: count, dtype: int64
#
# Age vs. is_minor
# 1.0 ← youngest minor
# 89.0 ← oldest non-minor
#
# Age vs. is_senior
# 65.0 ← youngest senior
#
# day_of_week vs. is_weekend
#    day_of_week  is_weekend
# 12      Friday       False
# 13      Monday       False
# 7     Saturday        True
# 1       Sunday        True
# 0     Thursday       False
# 4      Tuesday       False
# 16   Wednesday       False
#
# Simulated features:
# → simulated_medical_condition (controlled randomness)
# → first_time_visitor (Bernoulli 40%)
# first_time_visitor mean: 0.39589442815249265
# simulated_medical_condition distribution:
# simulated_medical_condition
# none        0.702346
# asthma      0.087977
# cardiac     0.077713
# diabetes    0.074780
# epilepsy    0.057185
# Name: proportion, dtype: float64
