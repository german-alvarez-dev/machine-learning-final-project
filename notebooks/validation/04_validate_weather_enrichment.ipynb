# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load enriched dataset
df = pd.read_parquet("../../data/processed/incidents_enriched.parquet")

# 1. Check presence of weather columns
weather_cols = ["temperature_max", "temperature_min", "precipitation_sum"]
print("\n🧪 Proporción de valores nulos en clima:")
print(df[weather_cols].isna().mean())

# 2. Summary stats
print("\n📊 Estadísticas descriptivas:")
print(df[weather_cols].describe())

# 3. Correlaciones climáticas
sns.pairplot(df[weather_cols].dropna())
plt.suptitle("Distribución y correlación entre variables climáticas", y=1.02)
plt.show()

# 4. Clima por estación del año
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x="season", y="temperature_max")
plt.title("Distribución de temperatura máxima por estación")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x="season", y="precipitation_sum")
plt.title("Distribución de precipitación por estación")
plt.show()

# 5. Clima y tipo de incidente
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x="incident_type", y="temperature_max")
plt.title("Temperatura máxima por tipo de incidente")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x="incident_type", y="precipitation_sum")
plt.title("Precipitación por tipo de incidente")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 🧪 Proporción de valores nulos en clima:
# temperature_max      0.0
# temperature_min      0.0
# precipitation_sum    0.0
# dtype: float64
#
# 📊 Estadísticas descriptivas:
#        temperature_max  temperature_min  precipitation_sum
# count       682.000000       682.000000         682.000000
# mean         27.614076        18.730792           3.074194
# std           4.727550         5.406948           5.346700
# min           8.900000         0.400000           0.000000
# 25%          25.000000        15.325000           0.000000
# 50%          28.900000        20.100000           0.300000
# 75%          31.000000        23.300000           4.000000
# max          36.200000        26.300000          38.700000
